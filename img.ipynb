# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tools import *

# %load_ext autoreload
# %autoreload 2

# %%
im = cv2.imread("imgs/nat1.jpg")
im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
print(im.shape)
# Out:
# (534, 800)

# %%
x,y = random_walk_coords(10000)
step = 10
x,y = x*step,y*step
plt.plot(x,y)
plt.show()
print(y)
print(x)
data = im[x,y]
print(data.shape)
# Out:
# [   0   10   10 ... -390 -400 -390]
# [   0    0   10 ... -180 -180 -180]
# (10000,)

# %%
fig = plt.figure()
fig.set_size_inches(22,10)
plt.plot(data)
plt.show()

# %%
N = 10
tao = 10

H = gen_hankel(data, N, tao)
print(H.shape)
u, s, v = np.linalg.svd(H.T, full_matrices=False)
H_hat = (v[:3])
plotly_3d(H_hat, title=f'tao={tao} N={N}')
plt.plot(s[0:10], '.-',)
plt.title("Hankel Singular Values")
plt.show()
plt.plot(u[:, :3])
plt.show()
# Out:
# (990, 10)
